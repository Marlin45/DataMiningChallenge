# %%
import numpy as np
import pandas as pd

from tensorflow import keras
import keras_tuner
from keras.models import Model
from keras import layers
from keras import Input
from keras.layers import Dense, LeakyReLU, ReLU, Conv1D
from tensorflow.keras.utils import plot_model 
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
rng = np.random.default_rng(12345)

# %%
def prep_signs():
    """
    reads train_signs and turns it into time series data with 30 columns and 24 hours for each person
    """
    
    df = pd.read_csv('train/train_signs.csv')

    df['charttime'] = pd.to_datetime(df['charttime'])

    #Creates new column 'firsttime' which is the time of first row for each patient
    first_time_row = df.groupby('patient_id')['charttime'].first()
    df['firsttime'] = df['patient_id'].map(first_time_row)
    # Sets the index as the time from the first reading so all patients start at 0 and go toward 24 hours
    df = df.set_index(df['charttime'] - df['firsttime'])
    df = df.drop(['charttime','firsttime'],axis=1)
    # Resamples data so all patients have exactly 24 hours
    df = df.groupby('patient_id').resample('h').mean()
    df = df.reindex(pd.MultiIndex.from_product([df.index.levels[0],pd.timedelta_range(start='00:00:00', end='23:00:00', freq='1h')]))
    df = df.groupby(level=['patient_id']).ffill().bfill()
    # Fills NA with zero, na here means a patient that never had a certain measurment taken
    df[df.isna()] = 0
    
    num_patients = len(df.index.levels[0])
    num_cols = len(df.columns)
    d = np.array(df)
    # patients * cols (30) * hours (24)
    d=np.reshape(d,(num_patients,num_cols,-1))
    d = np.swapaxes(d,1,2)
    
    X_train,X_test = np.split(rng.permutation(d),[int(d.shape[0]*0.8)],axis=0)

    scaler = StandardScaler()
    timesteps = X_train.shape[1]
    dim = X_train.shape[2]
    X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0]*X_train.shape[1],-1))
    X_test = scaler.transform(X_test.reshape(-1,dim))


    X_train = X_train.reshape(-1,timesteps,dim)
    X_test = X_test.reshape(-1,timesteps,dim)
    return X_train, X_test

# %%
def RNN_DAE_dimensionality_reducer(X_train,X_test,dim=30):
    """
        Reduces the dimension of X to whatever dim is given using Denoising Auto Encoder, this can lead to worse performance if dim is choosen poorly
    """
    # Specify how much noise to add
    level_of_noise=0.5

    # Add random noise based on sampling from Gaussian distribution
    X_train_noisy = X_train + level_of_noise * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)

    timesteps = X_train.shape[1]
    input_dim = X_train.shape[2] 
    latent_dim = dim

    inputs = keras.Input(shape=(timesteps, input_dim))
    encoded = layers.LSTM(latent_dim)(inputs)
    middle = layers.Dense(latent_dim)(encoded)

    decoded = layers.RepeatVector(timesteps)(middle)
    decoded = layers.LSTM(input_dim, return_sequences=True)(decoded)

    sequence_autoencoder = keras.Model(inputs, decoded,name='RNN-DAE')
    encoder = keras.Model(inputs, middle,name="Encoder")
    
    opt = keras.optimizers.Adam(learning_rate=0.001)
    sequence_autoencoder.compile(optimizer=opt, loss='mse')

    history = sequence_autoencoder.fit(X_train, X_train, epochs=1000, batch_size=128, verbose=1, validation_split=0.2)
    
    # Plot a loss chart
    display(sequence_autoencoder.summary())
    fig, ax = plt.subplots(figsize=(16,9), dpi=300)
    plt.title(label='DAE Model loss by Epoch', loc='center')
    ax.plot(history.history['loss'], label='Training Data', color='black')
    ax.plot(history.history['val_loss'], label='Test Data', color='red')
    ax.set(xlabel='Epoch', ylabel='Loss')
    plt.xticks(ticks=np.arange(len(history.history['loss'])), labels=np.arange(1, len(history.history['loss'])+1))
    plt.legend()

    plt.show()
    

    return encoder.predict(X_train), encoder.predict(X_test)

# %%
X_train,X_test = prep_signs()

# %%
X_train_latent, X_test_latent = RNN_DAE_dimensionality_reducer(X_train,X_test,30)
# Out:
# Epoch 1/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.8546 - val_loss: 1.1819
# Epoch 2/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9101 - val_loss: 1.1386
# Epoch 3/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8768 - val_loss: 1.1183
# Epoch 4/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8437 - val_loss: 1.1050
# Epoch 5/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8434 - val_loss: 1.0953
# Epoch 6/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7682 - val_loss: 1.0891
# Epoch 7/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9226 - val_loss: 1.0831
# Epoch 8/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7681 - val_loss: 1.0789
# Epoch 9/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8376 - val_loss: 1.0750
# Epoch 10/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8254 - val_loss: 1.0735
# Epoch 11/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8191 - val_loss: 1.0695
# Epoch 12/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7759 - val_loss: 1.0682
# Epoch 13/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7129 - val_loss: 1.0647
# Epoch 14/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9620 - val_loss: 1.0627
# Epoch 15/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7293 - val_loss: 1.0656
# Epoch 16/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8208 - val_loss: 1.0584
# Epoch 17/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7446 - val_loss: 1.0575
# Epoch 18/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7149 - val_loss: 1.0543
# Epoch 19/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6983 - val_loss: 1.0634
# Epoch 20/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7724 - val_loss: 1.0509
# Epoch 21/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7993 - val_loss: 1.0488
# Epoch 22/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7025 - val_loss: 1.0474
# Epoch 23/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8119 - val_loss: 1.0460
# Epoch 24/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6881 - val_loss: 1.0435
# Epoch 25/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8559 - val_loss: 1.0413
# Epoch 26/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8325 - val_loss: 1.0390
# Epoch 27/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7890 - val_loss: 1.0373
# Epoch 28/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7463 - val_loss: 1.0587
# Epoch 29/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7722 - val_loss: 1.0340
# Epoch 30/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7697 - val_loss: 1.0311
# Epoch 31/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8341 - val_loss: 1.0284
# Epoch 32/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7562 - val_loss: 1.0254
# Epoch 33/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6907 - val_loss: 1.0221
# Epoch 34/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8010 - val_loss: 1.0186
# Epoch 35/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8385 - val_loss: 1.0146
# Epoch 36/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7807 - val_loss: 1.0097
# Epoch 37/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6332 - val_loss: 1.0055
# Epoch 38/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7251 - val_loss: 1.0010
# Epoch 39/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7347 - val_loss: 0.9969
# Epoch 40/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7195 - val_loss: 0.9932
# Epoch 41/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7745 - val_loss: 0.9899
# Epoch 42/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7600 - val_loss: 0.9863
# Epoch 43/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7036 - val_loss: 0.9832
# Epoch 44/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7109 - val_loss: 0.9803
# Epoch 45/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7285 - val_loss: 0.9783
# Epoch 46/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7754 - val_loss: 0.9749
# Epoch 47/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6887 - val_loss: 0.9724
# Epoch 48/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7292 - val_loss: 0.9698
# Epoch 49/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6188 - val_loss: 0.9681
# Epoch 50/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9112 - val_loss: 0.9795
# Epoch 51/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5813 - val_loss: 0.9695
# Epoch 52/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6444 - val_loss: 0.9659
# Epoch 53/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6195 - val_loss: 0.9633
# Epoch 54/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6048 - val_loss: 0.9614
# Epoch 55/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7193 - val_loss: 0.9597
# Epoch 56/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6452 - val_loss: 0.9581
# Epoch 57/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6929 - val_loss: 0.9566
# Epoch 58/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6065 - val_loss: 0.9559
# Epoch 59/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6297 - val_loss: 0.9536
# Epoch 60/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6571 - val_loss: 0.9522
# Epoch 61/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6082 - val_loss: 0.9507
# Epoch 62/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6040 - val_loss: 0.9490
# Epoch 63/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6863 - val_loss: 0.9575
# Epoch 64/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6965 - val_loss: 0.9500
# Epoch 65/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7184 - val_loss: 0.9474
# Epoch 66/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5780 - val_loss: 0.9451
# Epoch 67/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6492 - val_loss: 0.9431
# Epoch 68/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7086 - val_loss: 0.9414
# Epoch 69/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8000 - val_loss: 0.9397
# Epoch 70/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6749 - val_loss: 0.9385
# Epoch 71/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6674 - val_loss: 0.9376
# Epoch 72/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6008 - val_loss: 0.9352
# Epoch 73/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7387 - val_loss: 0.9365
# Epoch 74/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6758 - val_loss: 0.9322
# Epoch 75/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6528 - val_loss: 0.9306
# Epoch 76/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6336 - val_loss: 0.9323
# Epoch 77/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.8025 - val_loss: 0.9274
# Epoch 78/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6782 - val_loss: 0.9260
# Epoch 79/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7785 - val_loss: 0.9251
# Epoch 80/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5806 - val_loss: 0.9233
# Epoch 81/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6230 - val_loss: 0.9224
# Epoch 82/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6910 - val_loss: 0.9198
# Epoch 83/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5795 - val_loss: 0.9193
# Epoch 84/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6303 - val_loss: 0.9170
# Epoch 85/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6782 - val_loss: 0.9161
# Epoch 86/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7464 - val_loss: 0.9152
# Epoch 87/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7884 - val_loss: 0.9170
# Epoch 88/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6039 - val_loss: 0.9113
# Epoch 89/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8741 - val_loss: 0.9656
# Epoch 90/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7820 - val_loss: 0.9133
# Epoch 91/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6597 - val_loss: 0.9091
# Epoch 92/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6451 - val_loss: 0.9065
# Epoch 93/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6175 - val_loss: 0.9045
# Epoch 94/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5905 - val_loss: 0.9029
# Epoch 95/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6909 - val_loss: 0.9012
# Epoch 96/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5382 - val_loss: 0.9033
# Epoch 97/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7238 - val_loss: 0.8992
# Epoch 98/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6313 - val_loss: 0.8975
# Epoch 99/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5322 - val_loss: 0.8961
# Epoch 100/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5654 - val_loss: 0.8951
# Epoch 101/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6789 - val_loss: 0.8946
# Epoch 102/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6397 - val_loss: 0.8940
# Epoch 103/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6209 - val_loss: 0.8910
# Epoch 104/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5696 - val_loss: 0.8890
# Epoch 105/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6545 - val_loss: 0.8877
# Epoch 106/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5104 - val_loss: 0.9013
# Epoch 107/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5787 - val_loss: 0.8859
# Epoch 108/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6136 - val_loss: 0.8845
# Epoch 109/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5680 - val_loss: 0.8971
# Epoch 110/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6109 - val_loss: 0.8824
# Epoch 111/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6507 - val_loss: 0.8813
# Epoch 112/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5914 - val_loss: 0.8808
# Epoch 113/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5854 - val_loss: 0.8793
# Epoch 114/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5834 - val_loss: 0.8793
# Epoch 115/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6148 - val_loss: 0.8774
# Epoch 116/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6113 - val_loss: 0.8791
# Epoch 117/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6624 - val_loss: 0.8758
# Epoch 118/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6691 - val_loss: 0.9513
# Epoch 119/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6290 - val_loss: 0.9027
# Epoch 120/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5508 - val_loss: 0.8855
# Epoch 121/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6457 - val_loss: 0.8780
# Epoch 122/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5603 - val_loss: 0.8760
# Epoch 123/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5891 - val_loss: 0.8748
# Epoch 124/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6236 - val_loss: 0.8738
# Epoch 125/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5668 - val_loss: 0.8730
# Epoch 126/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5428 - val_loss: 0.8723
# Epoch 127/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5689 - val_loss: 0.8716
# Epoch 128/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5633 - val_loss: 0.8711
# Epoch 129/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6707 - val_loss: 0.8704
# Epoch 130/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5494 - val_loss: 0.8697
# Epoch 131/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5795 - val_loss: 0.8696
# Epoch 132/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5287 - val_loss: 0.8686
# Epoch 133/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6020 - val_loss: 0.8680
# Epoch 134/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5562 - val_loss: 0.8674
# Epoch 135/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6019 - val_loss: 0.8668
# Epoch 136/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5196 - val_loss: 0.8671
# Epoch 137/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5706 - val_loss: 0.8657
# Epoch 138/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6537 - val_loss: 0.8649
# Epoch 139/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5917 - val_loss: 0.8773
# Epoch 140/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5627 - val_loss: 0.8640
# Epoch 141/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.6673 - val_loss: 0.8630
# Epoch 142/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6491 - val_loss: 0.8624
# Epoch 143/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5204 - val_loss: 0.8621
# Epoch 144/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6498 - val_loss: 0.8623
# Epoch 145/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6135 - val_loss: 0.8611
# Epoch 146/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5075 - val_loss: 0.8601
# Epoch 147/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4844 - val_loss: 0.8773
# Epoch 148/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5390 - val_loss: 0.8638
# Epoch 149/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6324 - val_loss: 0.8610
# Epoch 150/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5829 - val_loss: 0.8598
# Epoch 151/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5771 - val_loss: 0.8590
# Epoch 152/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5684 - val_loss: 0.8582
# Epoch 153/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5264 - val_loss: 0.8576
# Epoch 154/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5471 - val_loss: 0.8569
# Epoch 155/1000
# 66/69 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5939
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 X_train_latent, X_test_latent = RNN_DAE_dimensionality_reducer(X_train,X_test,30)
#
# Cell In[184], line 29, in RNN_DAE_dimensionality_reducer(X_train, X_test, dim)
#      25 sequence_autoencoder.compile(optimizer='adam', loss='mse')
#      28 # Fit the Denoising autoencoder model to reconstruct original images
# ---> 29 history = sequence_autoencoder.fit(X_train, X_train, epochs=1000, batch_size=128, verbose=1, validation_split=0.2)
#      31 # Plot a loss chart
#      32 display(sequence_autoencoder.summary())
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     323 for step, iterator in epoch_iterator.enumerate_epoch():
#     324     callbacks.on_train_batch_begin(step)
# --> 325     logs = self.train_function(iterator)
#     326     callbacks.on_train_batch_end(
#     327         step, self._pythonify_logs(logs)
#     328     )
#     329     if self.stop_training:
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
X_train_latent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 X_train_latent
#
# NameError: name 'X_train_latent' is not defined

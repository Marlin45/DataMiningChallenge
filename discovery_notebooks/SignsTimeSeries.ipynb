# %%
import numpy as np
import pandas as pd

from tensorflow import keras
import keras_tuner
from keras.models import Model
from keras import layers
from keras import Input
from keras.layers import Dense, LeakyReLU, ReLU, Conv1D
from tensorflow.keras.utils import plot_model 
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
rng = np.random.default_rng(12345)

# %%
def prep_signs():
    """
    reads train_signs and turns it into time series data with 30 columns and 24 hours for each person
    """
    
    df = pd.read_csv('train/train_signs.csv')

    df['charttime'] = pd.to_datetime(df['charttime'])

    #Creates new column 'firsttime' which is the time of first row for each patient
    first_time_row = df.groupby('patient_id')['charttime'].first()
    df['firsttime'] = df['patient_id'].map(first_time_row)
    # Sets the index as the time from the first reading so all patients start at 0 and go toward 24 hours
    df = df.set_index(df['charttime'] - df['firsttime'])
    df = df.drop(['charttime','firsttime'],axis=1)
    # Resamples data so all patients have exactly 24 hours
    df = df.groupby('patient_id').resample('h').mean()
    df = df.reindex(pd.MultiIndex.from_product([df.index.levels[0],pd.timedelta_range(start='00:00:00', end='23:00:00', freq='4h')]))
    df = df.groupby(level=['patient_id']).ffill().bfill()
    # Fills NA with zero, na here means a patient that never had a certain measurment taken
    df[df.isna()] = 0
    
    num_patients = len(df.index.levels[0])
    num_cols = len(df.columns)
    d = np.array(df)
    # patients * cols (30) * hours (24)
    d=np.reshape(d,(num_patients,num_cols,-1))
    d = np.swapaxes(d,1,2)
    
    X_train,X_test = np.split(rng.permutation(d),[int(d.shape[0]*0.8)],axis=0)

    scaler = StandardScaler()
    timesteps = X_train.shape[1]
    dim = X_train.shape[2]
    X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0]*X_train.shape[1],-1))
    X_test = scaler.transform(X_test.reshape(-1,dim))


    X_train = X_train.reshape(-1,timesteps,dim)
    X_test = X_test.reshape(-1,timesteps,dim)
    return X_train, X_test

# %%
def RNN_DAE_dimensionality_reducer(X_train,X_test,dim=30):
    """
        Reduces the dimension of X to whatever dim is given using Denoising Auto Encoder, this can lead to worse performance if dim is choosen poorly
    """
    # Specify how much noise to add
    level_of_noise=0.5

    # Add random noise based on sampling from Gaussian distribution
    X_train_noisy = X_train + level_of_noise * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)

    timesteps = X_train.shape[1]
    input_dim = X_train.shape[2] 
    latent_dim = dim

    inputs = keras.Input(shape=(timesteps, input_dim))
    encoded = layers.LSTM(latent_dim)(inputs)
    middle = layers.Dense(latent_dim)(encoded)

    decoded = layers.RepeatVector(timesteps)(middle)
    decoded = layers.LSTM(input_dim, return_sequences=True)(decoded)

    sequence_autoencoder = keras.Model(inputs, decoded,name='RNN-DAE')
    encoder = keras.Model(inputs, middle,name="Encoder")
    
    opt = keras.optimizers.Adam(learning_rate=0.001)
    sequence_autoencoder.compile(optimizer=opt, loss='mse')

    history = sequence_autoencoder.fit(X_train, X_train, epochs=1000, batch_size=128, verbose=1, validation_split=0.2)
    
    # Plot a loss chart
    display(sequence_autoencoder.summary())
    fig, ax = plt.subplots(figsize=(16,9), dpi=300)
    plt.title(label='DAE Model loss by Epoch', loc='center')
    ax.plot(history.history['loss'], label='Training Data', color='black')
    ax.plot(history.history['val_loss'], label='Test Data', color='red')
    ax.set(xlabel='Epoch', ylabel='Loss')
    plt.xticks(ticks=np.arange(len(history.history['loss'])), labels=np.arange(1, len(history.history['loss'])+1))
    plt.legend()

    plt.show()
    

    return encoder.predict(X_train), encoder.predict(X_test)

# %%
X_train,X_test = prep_signs()

# %%
X_train_latent, X_test_latent = RNN_DAE_dimensionality_reducer(X_train,X_test,30)
# Out:
# Epoch 1/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.9574 - val_loss: 0.8528
# Epoch 2/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9948 - val_loss: 0.6254
# Epoch 3/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8121 - val_loss: 0.5018
# Epoch 4/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6083 - val_loss: 0.4507
# Epoch 5/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4705 - val_loss: 0.4280
# Epoch 6/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6104 - val_loss: 0.4157
# Epoch 7/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5974 - val_loss: 0.4054
# Epoch 8/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5508 - val_loss: 0.3976
# Epoch 9/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5452 - val_loss: 0.3911
# Epoch 10/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5444 - val_loss: 0.3861
# Epoch 11/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5858 - val_loss: 0.3810
# Epoch 12/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4801 - val_loss: 0.3743
# Epoch 13/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5632 - val_loss: 0.3684
# Epoch 14/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5046 - val_loss: 0.3639
# Epoch 15/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5353 - val_loss: 0.3607
# Epoch 16/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5737 - val_loss: 0.3576
# Epoch 17/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5363 - val_loss: 0.3552
# Epoch 18/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4018 - val_loss: 0.3532
# Epoch 19/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4002 - val_loss: 0.3516
# Epoch 20/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4445 - val_loss: 0.3503
# Epoch 21/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4338 - val_loss: 0.3492
# Epoch 22/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5374 - val_loss: 0.3481
# Epoch 23/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4985 - val_loss: 0.3469
# Epoch 24/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4653 - val_loss: 0.3457
# Epoch 25/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3854 - val_loss: 0.3448
# Epoch 26/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4864 - val_loss: 0.3438
# Epoch 27/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3868 - val_loss: 0.3430
# Epoch 28/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4006 - val_loss: 0.3423
# Epoch 29/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4093 - val_loss: 0.3417
# Epoch 30/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3987 - val_loss: 0.3414
# Epoch 31/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5713 - val_loss: 0.3407
# Epoch 32/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3913 - val_loss: 0.3403
# Epoch 33/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5744 - val_loss: 0.3400
# Epoch 34/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4214 - val_loss: 0.3395
# Epoch 35/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4052 - val_loss: 0.3392
# Epoch 36/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3787 - val_loss: 0.3387
# Epoch 37/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5040 - val_loss: 0.3380
# Epoch 38/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3834 - val_loss: 0.3376
# Epoch 39/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4689 - val_loss: 0.3373
# Epoch 40/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4718 - val_loss: 0.3370
# Epoch 41/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4776 - val_loss: 0.3369
# Epoch 42/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4897 - val_loss: 0.3365
# Epoch 43/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4054 - val_loss: 0.3363
# Epoch 44/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4197 - val_loss: 0.3361
# Epoch 45/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4841 - val_loss: 0.3359
# Epoch 46/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5416 - val_loss: 0.3358
# Epoch 47/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5490 - val_loss: 0.3355
# Epoch 48/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4110 - val_loss: 0.3353
# Epoch 49/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4549 - val_loss: 0.3351
# Epoch 50/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5902 - val_loss: 0.3350
# Epoch 51/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4459 - val_loss: 0.3351
# Epoch 52/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4054 - val_loss: 0.3347
# Epoch 53/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5430 - val_loss: 0.3346
# Epoch 54/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3929 - val_loss: 0.3344
# Epoch 55/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4107 - val_loss: 0.3344
# Epoch 56/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4247 - val_loss: 0.3342
# Epoch 57/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4571 - val_loss: 0.3340
# Epoch 58/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4844 - val_loss: 0.3339
# Epoch 59/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4343 - val_loss: 0.3338
# Epoch 60/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3647 - val_loss: 0.3336
# Epoch 61/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4918 - val_loss: 0.3334
# Epoch 62/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4419 - val_loss: 0.3333
# Epoch 63/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4082 - val_loss: 0.3332
# Epoch 64/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3519 - val_loss: 0.3331
# Epoch 65/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5317 - val_loss: 0.3329
# Epoch 66/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5492 - val_loss: 0.3329
# Epoch 67/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4165 - val_loss: 0.3327
# Epoch 68/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4472 - val_loss: 0.3326
# Epoch 69/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5915 - val_loss: 0.3326
# Epoch 70/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4802 - val_loss: 0.3325
# Epoch 71/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4499 - val_loss: 0.3324
# Epoch 72/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4728 - val_loss: 0.3323
# Epoch 73/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4436 - val_loss: 0.3322
# Epoch 74/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4160 - val_loss: 0.3321
# Epoch 75/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5139 - val_loss: 0.3320
# Epoch 76/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4489 - val_loss: 0.3320
# Epoch 77/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4482 - val_loss: 0.3318
# Epoch 78/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5542 - val_loss: 0.3318
# Epoch 79/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5291 - val_loss: 0.3317
# Epoch 80/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4803 - val_loss: 0.3317
# Epoch 81/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4573 - val_loss: 0.3315
# Epoch 82/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5267 - val_loss: 0.3315
# Epoch 83/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3839 - val_loss: 0.3314
# Epoch 84/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4956 - val_loss: 0.3315
# Epoch 85/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3964 - val_loss: 0.3313
# Epoch 86/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4408 - val_loss: 0.3310
# Epoch 87/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3990 - val_loss: 0.3307
# Epoch 88/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4264 - val_loss: 0.3305
# Epoch 89/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3917 - val_loss: 0.3304
# Epoch 90/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4491 - val_loss: 0.3304
# Epoch 91/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4105 - val_loss: 0.3303
# Epoch 92/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4137 - val_loss: 0.3302
# Epoch 93/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4359 - val_loss: 0.3302
# Epoch 94/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5101 - val_loss: 0.3301
# Epoch 95/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4373 - val_loss: 0.3300
# Epoch 96/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4478 - val_loss: 0.3300
# Epoch 97/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4003 - val_loss: 0.3301
# Epoch 98/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4159 - val_loss: 0.3299
# Epoch 99/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4188 - val_loss: 0.3298
# Epoch 100/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4162 - val_loss: 0.3298
# Epoch 101/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5396 - val_loss: 0.3297
# Epoch 102/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4057 - val_loss: 0.3297
# Epoch 103/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3942 - val_loss: 0.3296
# Epoch 104/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4281 - val_loss: 0.3296
# Epoch 105/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5403 - val_loss: 0.3295
# Epoch 106/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4282 - val_loss: 0.3295
# Epoch 107/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3987 - val_loss: 0.3294
# Epoch 108/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3674 - val_loss: 0.3294
# Epoch 109/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4210 - val_loss: 0.3294
# Epoch 110/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5387 - val_loss: 0.3293
# Epoch 111/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4378 - val_loss: 0.3293
# Epoch 112/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5310 - val_loss: 0.3292
# Epoch 113/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4015 - val_loss: 0.3291
# Epoch 114/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3868 - val_loss: 0.3291
# Epoch 115/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3965 - val_loss: 0.3291
# Epoch 116/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5443 - val_loss: 0.3290
# Epoch 117/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3761 - val_loss: 0.3290
# Epoch 118/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4240 - val_loss: 0.3289
# Epoch 119/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3916 - val_loss: 0.3289
# Epoch 120/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3816 - val_loss: 0.3288
# Epoch 121/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5347 - val_loss: 0.3287
# Epoch 122/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4329 - val_loss: 0.3287
# Epoch 123/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4891 - val_loss: 0.3288
# Epoch 124/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4491 - val_loss: 0.3285
# Epoch 125/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4885 - val_loss: 0.3286
# Epoch 126/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4813 - val_loss: 0.3284
# Epoch 127/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4992 - val_loss: 0.3285
# Epoch 128/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4682 - val_loss: 0.3286
# Epoch 129/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4252 - val_loss: 0.3285
# Epoch 130/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4294 - val_loss: 0.3283
# Epoch 131/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4279 - val_loss: 0.3286
# Epoch 132/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4450 - val_loss: 0.3285
# Epoch 133/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4752 - val_loss: 0.3282
# Epoch 134/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4147 - val_loss: 0.3282
# Epoch 135/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4325 - val_loss: 0.3281
# Epoch 136/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4186 - val_loss: 0.3281
# Epoch 137/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3672 - val_loss: 0.3281
# Epoch 138/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5254 - val_loss: 0.3281
# Epoch 139/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3705 - val_loss: 0.3281
# Epoch 140/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4430 - val_loss: 0.3280
# Epoch 141/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4240 - val_loss: 0.3280
# Epoch 142/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3924 - val_loss: 0.3279
# Epoch 143/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4779 - val_loss: 0.3279
# Epoch 144/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4859 - val_loss: 0.3279
# Epoch 145/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6060 - val_loss: 0.3278
# Epoch 146/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3613 - val_loss: 0.3277
# Epoch 147/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3764 - val_loss: 0.3277
# Epoch 148/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4086 - val_loss: 0.3277
# Epoch 149/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3765 - val_loss: 0.3277
# Epoch 150/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4345 - val_loss: 0.3276
# Epoch 151/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3841 - val_loss: 0.3276
# Epoch 152/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4161 - val_loss: 0.3276
# Epoch 153/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4109 - val_loss: 0.3276
# Epoch 154/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4325 - val_loss: 0.3276
# Epoch 155/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4754 - val_loss: 0.3276
# Epoch 156/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4341 - val_loss: 0.3275
# Epoch 157/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4050 - val_loss: 0.3275
# Epoch 158/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3807 - val_loss: 0.3274
# Epoch 159/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3553 - val_loss: 0.3274
# Epoch 160/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3990 - val_loss: 0.3276
# Epoch 161/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4442 - val_loss: 0.3274
# Epoch 162/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4942 - val_loss: 0.3273
# Epoch 163/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4374 - val_loss: 0.3274
# Epoch 164/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3650 - val_loss: 0.3273
# Epoch 165/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4900 - val_loss: 0.3273
# Epoch 166/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4358 - val_loss: 0.3272
# Epoch 167/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4057 - val_loss: 0.3272
# Epoch 168/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4683 - val_loss: 0.3271
# Epoch 169/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5168 - val_loss: 0.3271
# Epoch 170/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4133 - val_loss: 0.3270
# Epoch 171/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4504 - val_loss: 0.3271
# Epoch 172/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3848 - val_loss: 0.3270
# Epoch 173/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4276 - val_loss: 0.3270
# Epoch 174/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4956 - val_loss: 0.3270
# Epoch 175/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4315 - val_loss: 0.3270
# Epoch 176/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4525 - val_loss: 0.3269
# Epoch 177/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4151 - val_loss: 0.3269
# Epoch 178/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5179 - val_loss: 0.3269
# Epoch 179/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4477 - val_loss: 0.3269
# Epoch 180/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3925 - val_loss: 0.3268
# Epoch 181/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3967 - val_loss: 0.3269
# Epoch 182/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4374 - val_loss: 0.3268
# Epoch 183/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3872 - val_loss: 0.3268
# Epoch 184/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5451 - val_loss: 0.3268
# Epoch 185/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4940 - val_loss: 0.3269
# Epoch 186/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3818 - val_loss: 0.3268
# Epoch 187/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4623 - val_loss: 0.3268
# Epoch 188/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4200 - val_loss: 0.3267
# Epoch 189/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3953 - val_loss: 0.3267
# Epoch 190/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3826 - val_loss: 0.3268
# Epoch 191/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5814 - val_loss: 0.3268
# Epoch 192/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4511 - val_loss: 0.3267
# Epoch 193/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4340 - val_loss: 0.3267
# Epoch 194/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4243 - val_loss: 0.3268
# Epoch 195/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4375 - val_loss: 0.3266
# Epoch 196/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3919 - val_loss: 0.3267
# Epoch 197/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4262 - val_loss: 0.3266
# Epoch 198/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5176 - val_loss: 0.3266
# Epoch 199/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5378 - val_loss: 0.3266
# Epoch 200/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4026 - val_loss: 0.3266
# Epoch 201/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4046 - val_loss: 0.3265
# Epoch 202/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5218 - val_loss: 0.3266
# Epoch 203/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4463 - val_loss: 0.3266
# Epoch 204/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3578 - val_loss: 0.3265
# Epoch 205/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4235 - val_loss: 0.3266
# Epoch 206/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3560 - val_loss: 0.3265
# Epoch 207/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3698 - val_loss: 0.3265
# Epoch 208/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4245 - val_loss: 0.3265
# Epoch 209/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5396 - val_loss: 0.3265
# Epoch 210/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4892 - val_loss: 0.3265
# Epoch 211/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4407 - val_loss: 0.3265
# Epoch 212/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4151 - val_loss: 0.3265
# Epoch 213/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4089 - val_loss: 0.3265
# Epoch 214/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4837 - val_loss: 0.3265
# Epoch 215/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4598 - val_loss: 0.3264
# Epoch 216/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4954 - val_loss: 0.3264
# Epoch 217/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4214 - val_loss: 0.3264
# Epoch 218/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3677 - val_loss: 0.3264
# Epoch 219/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4375 - val_loss: 0.3264
# Epoch 220/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4301 - val_loss: 0.3263
# Epoch 221/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3995 - val_loss: 0.3263
# Epoch 222/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4211 - val_loss: 0.3264
# Epoch 223/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4350 - val_loss: 0.3263
# Epoch 224/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4303 - val_loss: 0.3264
# Epoch 225/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4116 - val_loss: 0.3264
# Epoch 226/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5157 - val_loss: 0.3263
# Epoch 227/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3836 - val_loss: 0.3263
# Epoch 228/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4713 - val_loss: 0.3263
# Epoch 229/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3909 - val_loss: 0.3263
# Epoch 230/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4230 - val_loss: 0.3263
# Epoch 231/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4035 - val_loss: 0.3262
# Epoch 232/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4392 - val_loss: 0.3263
# Epoch 233/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4064 - val_loss: 0.3263
# Epoch 234/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4171 - val_loss: 0.3262
# Epoch 235/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4686 - val_loss: 0.3263
# Epoch 236/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4965 - val_loss: 0.3262
# Epoch 237/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4160 - val_loss: 0.3263
# Epoch 238/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4256 - val_loss: 0.3261
# Epoch 239/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4582 - val_loss: 0.3261
# Epoch 240/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4720 - val_loss: 0.3262
# Epoch 241/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4321 - val_loss: 0.3262
# Epoch 242/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4758 - val_loss: 0.3261
# Epoch 243/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3834 - val_loss: 0.3261
# Epoch 244/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4528 - val_loss: 0.3261
# Epoch 245/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7219 - val_loss: 0.3260
# Epoch 246/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4145 - val_loss: 0.3260
# Epoch 247/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4296 - val_loss: 0.3260
# Epoch 248/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3846 - val_loss: 0.3261
# Epoch 249/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4387 - val_loss: 0.3262
# Epoch 250/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3940 - val_loss: 0.3265
# Epoch 251/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5063 - val_loss: 0.3261
# Epoch 252/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4477 - val_loss: 0.3261
# Epoch 253/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3686 - val_loss: 0.3260
# Epoch 254/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4453 - val_loss: 0.3260
# Epoch 255/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4202 - val_loss: 0.3260
# Epoch 256/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4770 - val_loss: 0.3260
# Epoch 257/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3459 - val_loss: 0.3260
# Epoch 258/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4104 - val_loss: 0.3260
# Epoch 259/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5198 - val_loss: 0.3260
# Epoch 260/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4112 - val_loss: 0.3260
# Epoch 261/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3633 - val_loss: 0.3259
# Epoch 262/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3831 - val_loss: 0.3261
# Epoch 263/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4123 - val_loss: 0.3259
# Epoch 264/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3891 - val_loss: 0.3260
# Epoch 265/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4522 - val_loss: 0.3259
# Epoch 266/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3697 - val_loss: 0.3259
# Epoch 267/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3716 - val_loss: 0.3259
# Epoch 268/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3948 - val_loss: 0.3259
# Epoch 269/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4870 - val_loss: 0.3259
# Epoch 270/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4340 - val_loss: 0.3258
# Epoch 271/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4005 - val_loss: 0.3258
# Epoch 272/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4851 - val_loss: 0.3258
# Epoch 273/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4105 - val_loss: 0.3259
# Epoch 274/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4968 - val_loss: 0.3259
# Epoch 275/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5536 - val_loss: 0.3257
# Epoch 276/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4557 - val_loss: 0.3258
# Epoch 277/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3418 - val_loss: 0.3257
# Epoch 278/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3536 - val_loss: 0.3257
# Epoch 279/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3804 - val_loss: 0.3257
# Epoch 280/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4508 - val_loss: 0.3258
# Epoch 281/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3585 - val_loss: 0.3257
# Epoch 282/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4277 - val_loss: 0.3257
# Epoch 283/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3981 - val_loss: 0.3257
# Epoch 284/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5347 - val_loss: 0.3258
# Epoch 285/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4990 - val_loss: 0.3256
# Epoch 286/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5593 - val_loss: 0.3256
# Epoch 287/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3680 - val_loss: 0.3256
# Epoch 288/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4203 - val_loss: 0.3257
# Epoch 289/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3552 - val_loss: 0.3257
# Epoch 290/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4598 - val_loss: 0.3257
# Epoch 291/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3889 - val_loss: 0.3256
# Epoch 292/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4146 - val_loss: 0.3256
# Epoch 293/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4269 - val_loss: 0.3256
# Epoch 294/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4260 - val_loss: 0.3256
# Epoch 295/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4214 - val_loss: 0.3258
# Epoch 296/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3640 - val_loss: 0.3256
# Epoch 297/1000
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3750 - val_loss: 0.3256
# Epoch 298/1000
# 24/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4121
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 X_train_latent, X_test_latent = RNN_DAE_dimensionality_reducer(X_train,X_test,30)
#
# Cell In[191], line 28, in RNN_DAE_dimensionality_reducer(X_train, X_test, dim)
#      25 opt = keras.optimizers.Adam(learning_rate=0.001)
#      26 sequence_autoencoder.compile(optimizer=opt, loss='mse')
# ---> 28 history = sequence_autoencoder.fit(X_train, X_train, epochs=1000, batch_size=128, verbose=1, validation_split=0.2)
#      30 # Plot a loss chart
#      31 display(sequence_autoencoder.summary())
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     323 for step, iterator in epoch_iterator.enumerate_epoch():
#     324     callbacks.on_train_batch_begin(step)
# --> 325     logs = self.train_function(iterator)
#     326     callbacks.on_train_batch_end(
#     327         step, self._pythonify_logs(logs)
#     328     )
#     329     if self.stop_training:
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
X_train_latent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 X_train_latent
#
# NameError: name 'X_train_latent' is not defined
